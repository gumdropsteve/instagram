# %%
import pandas as pd
# load mass dataframe
df=pd.read_csv('data/scraped/All_users_ttv.princearthur_20190613_2119.csv')
# tell us about it
print(df.info())
# give us a sample
df.sample(7)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1899 entries, 0 to 1898
# Data columns (total 20 columns):
# id                        1899 non-null int64
# username                  1899 non-null object
# full_name                 1756 non-null object
# user_profile              1899 non-null object
# followed_by_viewer        1899 non-null bool
# requested_by_viewer       1899 non-null bool
# user_follows              1899 non-null bool
# user_followed_by          1899 non-null bool
# profile_pic_url           1899 non-null object
# profile_pic_url_hd        1898 non-null object
# is_private                1899 non-null bool
# follows_count             1899 non-null int64
# followed_by_count         1899 non-null int64
# media_count               1899 non-null int64
# latestPostDate            1720 non-null object
# follows_viewer            1899 non-null bool
# biography                 1708 non-null object
# is_verified               1899 non-null bool
# ...

# %%
# dataframe of followers
follows_princearthur=[url for url in df.loc[df.user_followed_by==True].user_profile]
# dataframe of accounts we're following
princearthur_follows=[url for url in df.loc[df.user_follows==True].user_profile]
# dataframe of accounts we're following that do not follow us
eligible_for_unfollowing=[url for url in princearthur_follows if url not in follows_princearthur]

# %%
len(follows_princearthur),len(princearthur_follows),len(eligible_for_unfollowing)
# Out:
# (1458, 1080, 441)
