# %%
import pandas as pd
import numpy as np

# load accounts & info on followed
follows_users = pd.read_csv('data/follows_users_ttv_princearthur_20190421_2205.csv')
# load accounts & info on following
by_users = pd.read_csv('data/followed_by_users_ttv_princearthru_20190421_1846.csv')

# %%
follows_users.head()
# Out:
#            id         username            full_name  \
# 0  8416262456   itz._carlxs405           $CARLXS$🤪🤫
# 1  2077685663            ninja        Tyler Blevins
# 2   327749245      mlgofficial  Major League Gaming
# 3  5573747484  davidarnett2004              Davidar
# 4   269438978          sonnym2                   Zz
#
#                                 user_profile  followed_by_viewer  \
# 0   https://www.instagram.com/itz._carlxs405                True
# 1            https://www.instagram.com/ninja                True
# 2      https://www.instagram.com/mlgofficial                True
# 3  https://www.instagram.com/davidarnett2004                True
# 4          https://www.instagram.com/sonnym2                True
#
#    requested_by_viewer  user_follows  user_followed_by  \
# 0                False          True             False
# 1                False          True             False
# 2                False          True             False
# 3                False          True             False
# 4                False          True             False
#
#                                      profile_pic_url  profile_pic_url_hd  \
# 0  https://scontent-sjc3-1.cdninstagram.com/vp/5d...                 NaN
# 1  https://scontent-sjc3-1.cdninstagram.com/vp/0f...                 NaN
# 2  https://scontent-sjc3-1.cdninstagram.com/vp/c5...                 NaN
# 3  https://instagram.fewr1-3.fna.fbcdn.net/vp/fa6...                 NaN
# 4  https://scontent-sjc3-1.cdninstagram.com/vp/7d...                 NaN
#
#    is_private  follows_count  followed_by_count  media_count  latestPostDate  \
# 0         NaN            NaN                NaN          NaN             NaN
# 1         NaN            NaN                NaN          NaN             NaN
# 2         NaN            NaN                NaN          NaN             NaN
# 3         NaN            NaN                NaN          NaN             NaN
# 4         NaN            NaN                NaN          NaN             NaN
#
#    follows_viewer  biography  is_verified
# 0             NaN        NaN        False
# 1             NaN        NaN         True
# 2             NaN        NaN         True
# 3             NaN        NaN        False
# 4             NaN        NaN        False

# %%
by_users.head()
# Out:
#             id              username            full_name  \
# 0   8250864621   solotendapromosindo  solotendapromosindo
# 1    191638865       crossfitfortius             Fortius™
# 2  12865793762  harvey.kathleen61301      Harvey Kathleen
# 3  10891351352               imgenax                Genax
# 4  10025331126         games_moment_  🎮❣️Gamergirl_lyh❣️🎮
#
#                                      user_profile  followed_by_viewer  \
# 0   https://www.instagram.com/solotendapromosindo               False
# 1       https://www.instagram.com/crossfitfortius               False
# 2  https://www.instagram.com/harvey.kathleen61301               False
# 3               https://www.instagram.com/imgenax               False
# 4         https://www.instagram.com/games_moment_               False
#
#    requested_by_viewer  user_follows  user_followed_by  \
# 0                False         False              True
# 1                False         False              True
# 2                False         False              True
# 3                False         False              True
# 4                False         False              True
#
#                                      profile_pic_url  profile_pic_url_hd  \
# 0  https://scontent-sjc3-1.cdninstagram.com/vp/c3...                 NaN
# 1  https://scontent-sjc3-1.cdninstagram.com/vp/57...                 NaN
# 2  https://scontent-sjc3-1.cdninstagram.com/vp/5b...                 NaN
# 3  https://scontent-sjc3-1.cdninstagram.com/vp/0f...                 NaN
# 4  https://scontent-sjc3-1.cdninstagram.com/vp/ea...                 NaN
#
#    is_private  follows_count  followed_by_count  media_count  latestPostDate  \
# 0         NaN            NaN                NaN          NaN             NaN
# 1         NaN            NaN                NaN          NaN             NaN
# 2         NaN            NaN                NaN          NaN             NaN
# 3         NaN            NaN                NaN          NaN             NaN
# 4         NaN            NaN                NaN          NaN             NaN
#
#    follows_viewer  biography  is_verified
# 0             NaN        NaN        False
# 1             NaN        NaN        False
# 2             NaN        NaN        False
# 3             NaN        NaN        False
# 4             NaN        NaN        False

# %%
len(follows_users.columns),len(by_users.columns),sum(follows_users.columns == by_users.columns),sum(follows_users.columns != by_users.columns)
# Out:
# (18, 18, 18, 0)

# %%
follows_users.user_profile.head()
# Out:
# 0     https://www.instagram.com/itz._carlxs405
# 1              https://www.instagram.com/ninja
# 2        https://www.instagram.com/mlgofficial
# 3    https://www.instagram.com/davidarnett2004
# 4            https://www.instagram.com/sonnym2
# Name: user_profile, dtype: object

# %%
by_users.user_profile.head()
# Out:
# 0     https://www.instagram.com/solotendapromosindo
# 1         https://www.instagram.com/crossfitfortius
# 2    https://www.instagram.com/harvey.kathleen61301
# 3                 https://www.instagram.com/imgenax
# 4           https://www.instagram.com/games_moment_
# Name: user_profile, dtype: object

# %%
len(follows_users.user_profile),len(by_users.user_profile)
# Out:
# (7290, 1481)

# %%
"""ACTUAL"""
# 7,289 following
# 1,479 followers
pass

# %% [markdown]
# - ***notes***:
#     - 2 over on followers
#     - 1 over on following

# %%
# collection of people we follow who are following us
followers_being_followed = [user for user in follows_users.username if user in by_users.username]
# collection of people we follow who are NOT following us
non_followers_being_followed = [user for user in follows_users.username if user not in by_users.username]

# %%
len(followers_being_followed),len(non_followers_being_followed)
# Out:
# (0, 7290)

# %%
by_users.loc[by_users.username == 'winstonr2']
# Out:
#             id   username full_name                         user_profile  \
# 1480  54528654  winstonr2   Winston  https://www.instagram.com/winstonr2
#
#       followed_by_viewer  requested_by_viewer  user_follows  user_followed_by  \
# 1480                True                False         False              True
#
#                                         profile_pic_url  profile_pic_url_hd  \
# 1480  https://scontent-sjc3-1.cdninstagram.com/vp/fa...                 NaN
#
#       is_private  follows_count  followed_by_count  media_count  \
# 1480         NaN            NaN                NaN          NaN
#
#       latestPostDate  follows_viewer  biography  is_verified
# 1480             NaN             NaN        NaN        False

# %%
follows_users.loc[follows_users.username == 'winstonr2']
# Out:
#             id   username full_name                         user_profile  \
# 1642  54528654  winstonr2   Winston  https://www.instagram.com/winstonr2
#
#       followed_by_viewer  requested_by_viewer  user_follows  user_followed_by  \
# 1642                True                False          True             False
#
#                                         profile_pic_url  profile_pic_url_hd  \
# 1642  https://scontent-sjc3-1.cdninstagram.com/vp/fa...                 NaN
#
#       is_private  follows_count  followed_by_count  media_count  \
# 1642         NaN            NaN                NaN          NaN
#
#       latestPostDate  follows_viewer  biography  is_verified
# 1642             NaN             NaN        NaN        False

# %%
by_usernames = np.array(by_users.user_profile)
follows_usernames = np.array(follows_users.user_profile)

# %%
# count coexisting
_=0
for i in follows_usernames:
    if i in by_usernames:
        _+=1
print(_)
# Out:
# 669

# %% [markdown]
# - ***actions***:
#     - we will unfollow all except 669 users

# %%
# collect urls to profiles to unfollow 
unfollow_these = [user for user in follows_usernames if user not in by_usernames]
# collect urls to keep (double check overlap)
keep_these = [user for user in follows_usernames if user in by_usernames]

# %%
# check overlap
safe_check = 0
for user in keep_these:
    if user in unfollow_these:
        raise Exception('f')
    else:
        safe_check += 1
# double check overlap
if safe_check != len(keep_these):
    raise Exception('ff')

# %%
print(unfollow_these[0])
# Out:
# https://www.instagram.com/ninja

# %% [markdown]
# - ***notes***:
#     - ready for unfollowin
# - ***actions***:
#     - take list to Selenium webdriver (likely gecko)
#         - load page of user being followed
#             - click following button
#                 - click unfollowing button
#         - repeat

# %%
# for loading and sorting data regarding accounts of interest 
import numpy as np
import pandas as pd
# for taking action on accounts of interest
import time
from time import sleep
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException      
# for documentation
import csv
import datetime
# loading login info (adjust to import yours or take this line out and input near bottom)
from _pile import utv, ptv

# time it 
now = time.time()
# start time
print(f"start = {datetime.datetime.now()}")

# load accounts & info on followed
follows_users = pd.read_csv('data/follows_users_ttv_princearthur_20190421_2205.csv')
# load accounts & info on following
by_users = pd.read_csv('data/followed_by_users_ttv_princearthru_20190421_1846.csv')

# url of each account following us
by_usernames = np.array(by_users.user_profile)
# url of each account we follow
follows_usernames = np.array(follows_users.user_profile)

# collect urls of profiles to unfollow 
unfollow_these = [user for user in follows_usernames if user not in by_usernames]
# collect urls of profiles we do NOT want to unfollow (double check overlap)
keep_these = [user for user in follows_usernames if user in by_usernames]

# set count for safety check (make sure we don't unfollow anyone we don't want to)
safe_check = 0
# check overlap
for user in keep_these:
    # does user coexist?
    if user in unfollow_these:
        # display that user coexists
        raise Exception(f'if user in unfollow_these : {user}')
    # otherwise
    else:
        # add to count of non coexisting
        safe_check += 1
# double check overlap via count
if safe_check != len(keep_these):
    # display unequal counts
    raise Exception(f'safe_check != len(keep_these) : {safe_check} != {len(keep_these)}')
    
# create csv to store accounts we have unfollowed (so do not re-follow in future)
with open('accounts_ttvpa_used_to_follow.csv', 'a', newline='') as file:
    # set writer to this file
    the_writer = csv.writer(file)
    # write column names
    the_writer.writerow(['account_id','username','profile_url','time_unfollowed'])
    

# geckodriver options setup
options = webdriver.FirefoxOptions()  
# block popups (set push notifications to False)
options.set_preference('dom.push.enabled', False) 

# set instagram.com
instagram = "https://www.instagram.com/"
# set path for login button from instagram.com (xpath)
log_in = "//a[@href='/accounts/login/?source=auth_switcher']"
# set path for user box for login page (xpath)
user_box = "//input[@name='username']"
# set path for password box for login page (xpath)
pass_box = "//input[@name='password']"
# xpath ; following button 
following_button = '//button[contains(text(),"Following")]'
# xpath ; unfollow button 
unfollow_button = '//button[contains(text(),"Unfollow")]'


def check_xpath(webdriver, xpath, click=False, send_keys=False, keys=None):
    """
    checks if an xpath exists on the current page

    inputs)
        > webdriver
            >> driver being used
        > xpath
            >> xpath in question
        > click
            >> if clicking the element once/if found
        > send_keys
            >> if sending keys to element once/if found
        > keys
            >> keys being sent if sending keys (i.e. send_keys=True)
    """
    # test this 
    try:
        # find xpath in question
        find_element = webdriver.find_element_by_xpath(xpath)
        # element was found, step 1 complete
        # are we clicking
        if click == True:
            # yes, so click
            find_element.click()
            # hedge time
            sleep(3)
        # are we sending keys
        if send_keys == True:
            # yes, so send them
            find_element.send_keys(keys)
            # hedge time
            sleep(3)
    # if it didn't work
    except NoSuchElementException:
        print(f'NoSuchElementException : {xpath}')
    pass


# define how we will log in 
def login(usr, pwd, driver):
    """
    logs in to instagram 
    
    inputs) 
        >> usr
            > username, email, or phone number of account 
        >> pwd
            > password of account 
        >> driver
            > webdriver being used (pre-defined)
    """
    # load base instagram 
    driver.get(instagram)
    # hedge load time and misc
    sleep(3)
    # find and tag the login button 
    login_button = driver.find_element_by_xpath(log_in)
    # click to login
    login_button.click()
    # hedge load time and etc..
    sleep(3)
    # find and tag the username, email, or phone number box
    user_name_elem = driver.find_element_by_xpath(user_box)
    # delete anything that may be in there
    user_name_elem.clear()
    # type in our user info 
    user_name_elem.send_keys(usr)
    # take a breath
    sleep(1)
    # find and tag the pass box
    passworword_elem = driver.find_element_by_xpath(pass_box)
    # clear out anything that may be in there
    passworword_elem.clear()
    # plug in our pass info 
    passworword_elem.send_keys(pwd)
    # take a breath
    sleep(1)
    # effectively hit 'enter' (logging in)
    passworword_elem.send_keys(Keys.RETURN)
    # and give it a bit to process, maybe extra load time, etc..
    sleep(3)

# set username 
user = utv
# set passwrd
pwrd = ptv

# set webdriver w/ options (activates driver, screen should appear)
driver = webdriver.Firefox(options=options) 

# log in so we can get it poppin 
login(usr=user, pwd=pwrd, driver=driver)

# define unfollow method and process 
def unfollow(accounts=unfollow_these, start=0, n=100):
    """
    goes through list of accounts
        loads the current account's profile url
            makes sure that account is cleared for unfollowing
                unfollows the account 
    inputs)
        >> accounts
            > list of accounts eligible for unfollowing
        >> n
            > number of those accounts we're going to unfollow right now
                >> rec: n < 250 , due to mass unfollowing (usually) being prohibited 
                >> default: 1 (i.e. two (2) accounts)
    """
    # go through first n urls
    for user_url in accounts[start:n]:  # account after succ..
        print(f'user_url = {user_url}')  # for testing
        """
        prime the mission
        """
        # load the url
        driver.get(user_url)
        # wait for profile page to load
        sleep(3)
        # test for/find and click the 'following' button  (this is an issue)
        check_xpath(webdriver=driver, xpath=following_button, click=True, send_keys=False, keys=None)
        # wait a bit (to seem human, for web loading, and not unfollow too quickly)
        sleep(2)
        """
        set up recording of transaction
        """
        # pull the account's record
        this_account = follows_users.loc[follows_users.user_profile == user_url]
        # account's id number
        account_id = this_account.id
        for i in account_id:
            account_id = i
        # account's username
        username = this_account.username
        # something weird
        for i in username:
            # can't remember specifix
            username = i
        # account's url
        profile_url = this_account.user_profile
        # happens here too (surprise)
        for i in profile_url:
            # maybe something with ""s or something else probably maybe
            profile_url = i
        # double check 
        if str(profile_url) != str(user_url):
            # let us know if it's not adding up
            raise Exception(f'profile_url != user_url : {profile_url} != {user_url}')
        # set values to be recorded (to the ranch!)
        fields = [account_id, username, profile_url, datetime.datetime.now()]
        """
        execute
        """
        # test for/find and click 'unfollow' button in popup (this is an issue)
        check_xpath(webdriver=driver, xpath=unfollow_button, click=True, send_keys=False, keys=None)
        """
        record the transaction
        """
        # open up the csv
        with open('accounts_ttvpa_used_to_follow.csv', 'a') as _f:
            # fit the writer
            writer = csv.writer(_f)
            # document the transaction
            writer.writerow(fields)
        # pause so we can do this for a long time without breaching the unfollow limit 
        sleep(16)  # combined sleep prior = 16 sec; +16 = 32; +runtime ~40??
        # believe it to be: 160/hour; with this we will hit about 90 an hour 

# let's do it (399 accounts)
unfollow(accounts=unfollow_these, start=1250, n=1500)
# end time
then = time.time()
# how long did this take?
runtime = now-then
# show us
print(f"runtime = {runtime}")
print(f"end = {datetime.datetime.now()}")
# Out:
# start = 2019-05-19 15:32:24.519343
# user_url = https://www.instagram.com/stuewing
# user_url = https://www.instagram.com/nathalielaukens
# user_url = https://www.instagram.com/amina_zia1
# user_url = https://www.instagram.com/umami00
# user_url = https://www.instagram.com/sundarandi
# user_url = https://www.instagram.com/rustdesert
# user_url = https://www.instagram.com/mairiharland
# user_url = https://www.instagram.com/vania.lot
# user_url = https://www.instagram.com/soo.trash
# user_url = https://www.instagram.com/hyperfyyerleo
# NoSuchElementException : //button[contains(text(),"Following")]
# NoSuchElementException : //button[contains(text(),"Unfollow")]
# user_url = https://www.instagram.com/mkalamity
# user_url = https://www.instagram.com/theaquarianisback
# user_url = https://www.instagram.com/sup_killa_
# user_url = https://www.instagram.com/besttwitchclip
# user_url = https://www.instagram.com/fluffymarshy
# user_url = https://www.instagram.com/dominicvstheunknown
# user_url = https://www.instagram.com/mimzyclips
# user_url = https://www.instagram.com/flash_community
# user_url = https://www.instagram.com/ssillylilly17
# user_url = https://www.instagram.com/playtimesv
# user_url = https://www.instagram.com/gamingvirgin
# user_url = https://www.instagram.com/klypxo.twitch
# user_url = https://www.instagram.com/kim.dae_hyun_
# user_url = https://www.instagram.com/danceandmince
# user_url = https://www.instagram.com/leah.93_
# user_url = https://www.instagram.com/wish_con52
# user_url = https://www.instagram.com/sufi699
# user_url = https://www.instagram.com/b_for_black
# user_url = https://www.instagram.com/vmalaguti
# user_url = https://www.instagram.com/aor_ketwarang
# user_url = https://www.instagram.com/michael103083
# user_url = https://www.instagram.com/a_fork_in_a_world_of_soup
# user_url = https://www.instagram.com/coryryno
# user_url = https://www.instagram.com/ashlyinwonderland
# user_url = https://www.instagram.com/butyoulikeweird
# user_url = https://www.instagram.com/agentofmisfortune
# user_url = https://www.instagram.com/9to5technews
# user_url = https://www.instagram.com/maui_art
# user_url = https://www.instagram.com/miguel_a._jimenez_romero
# user_url = https://www.instagram.com/clint_tms
# user_url = https://www.instagram.com/plushimishop
# user_url = https://www.instagram.com/emcmoves
# user_url = https://www.instagram.com/thezombiegame
# user_url = https://www.instagram.com/dancing.with.the.starss
# user_url = https://www.instagram.com/peacheszmc
# user_url = https://www.instagram.com/clemanddaryl
# user_url = https://www.instagram.com/coasterfreakofficial
# user_url = https://www.instagram.com/90x.r
# user_url = https://www.instagram.com/alfa_group_miniature_addiction
# user_url = https://www.instagram.com/elteacherpeleador
# user_url = https://www.instagram.com/slash_and_trash
# user_url = https://www.instagram.com/master_chungy
# user_url = https://www.instagram.com/nuclearfps
# user_url = https://www.instagram.com/monikafelicesmith
# user_url = https://www.instagram.com/nehasglam
# user_url = https://www.instagram.com/taniradove
# user_url = https://www.instagram.com/shitpxst_af
# user_url = https://www.instagram.com/nkiicmk
# user_url = https://www.instagram.com/jr_picazo_
# user_url = https://www.instagram.com/thedailyfanboy
# user_url = https://www.instagram.com/akenno_230
# user_url = https://www.instagram.com/angc115
# NoSuchElementException : //button[contains(text(),"Following")]
# NoSuchElementException : //button[contains(text(),"Unfollow")]
# user_url = https://www.instagram.com/nervziel
# user_url = https://www.instagram.com/tdark_killer
# user_url = https://www.instagram.com/primisrichtofen
# user_url = https://www.instagram.com/skullthekid
# user_url = https://www.instagram.com/lagginho
# user_url = https://www.instagram.com/ozcil_oz
# user_url = https://www.instagram.com/icelandic.powerhouse
# user_url = https://www.instagram.com/reecenugent22
# user_url = https://www.instagram.com/_ninalex_
# user_url = https://www.instagram.com/calloflucy
# user_url = https://www.instagram.com/treyarch_quality_memes
# user_url = https://www.instagram.com/thatsovietrepublicofcringe
# user_url = https://www.instagram.com/confumused
# user_url = https://www.instagram.com/ncxaesthetic
# user_url = https://www.instagram.com/hitari.co.uk
# user_url = https://www.instagram.com/lalithcheekoti
# user_url = https://www.instagram.com/erickfabbio
# user_url = https://www.instagram.com/alb.teknoloji
# user_url = https://www.instagram.com/thedarth_b
# user_url = https://www.instagram.com/trymtherogue
# user_url = https://www.instagram.com/miss___slaughter
# user_url = https://www.instagram.com/gigalactic
# user_url = https://www.instagram.com/nahrune
# user_url = https://www.instagram.com/babeswhogame
# user_url = https://www.instagram.com/creative.happyness
# user_url = https://www.instagram.com/nannershots
# user_url = https://www.instagram.com/ockamgamer
# user_url = https://www.instagram.com/datshadowwolf
# user_url = https://www.instagram.com/fablefire
# user_url = https://www.instagram.com/outlawking305
# user_url = https://www.instagram.com/mr_terry_aki
# user_url = https://www.instagram.com/nk_omr
# NoSuchElementException : //button[contains(text(),"Following")]
# NoSuchElementException : //button[contains(text(),"Unfollow")]
# user_url = https://www.instagram.com/bo4vidul
# user_url = https://www.instagram.com/call_of_duty_bo4_italia
# user_url = https://www.instagram.com/dbs_gamers
# user_url = https://www.instagram.com/ownage_everyday
# user_url = https://www.instagram.com/kllr_bnny
# user_url = https://www.instagram.com/fias_clan
# user_url = https://www.instagram.com/seannmcclurg
# user_url = https://www.instagram.com/apexbible
# user_url = https://www.instagram.com/pinclubofficial
# user_url = https://www.instagram.com/disaster137b
# user_url = https://www.instagram.com/itsdethkloch
# user_url = https://www.instagram.com/cjay_games
# user_url = https://www.instagram.com/oblivious77_
# user_url = https://www.instagram.com/kevin_stardust
# user_url = https://www.instagram.com/nunya__bizness
# user_url = https://www.instagram.com/sliimwolf
# user_url = https://www.instagram.com/bo4_cod_news
# user_url = https://www.instagram.com/cocoa.crips
# user_url = https://www.instagram.com/scapeosm
# user_url = https://www.instagram.com/tripler_r3
# user_url = https://www.instagram.com/riinkaku
# user_url = https://www.instagram.com/scoorpio_
# user_url = https://www.instagram.com/im_jayhym
# user_url = https://www.instagram.com/marco5311
# user_url = https://www.instagram.com/skyy_limit
# user_url = https://www.instagram.com/iamtilewa_
# user_url = https://www.instagram.com/simpleplandaily
# user_url = https://www.instagram.com/blackout_rsm
# user_url = https://www.instagram.com/the_grim_old_gamer
# user_url = https://www.instagram.com/_eleonoracarraro
# user_url = https://www.instagram.com/gamerfriendspod
# user_url = https://www.instagram.com/solethetoycollector
# NoSuchElementException : //button[contains(text(),"Following")]
# NoSuchElementException : //button[contains(text(),"Unfollow")]
# user_url = https://www.instagram.com/viyxr
# user_url = https://www.instagram.com/eric_tron
# user_url = https://www.instagram.com/jacob_vip45
# user_url = https://www.instagram.com/daltoosh
# user_url = https://www.instagram.com/7manshul
# user_url = https://www.instagram.com/ultim8gaming_net
# user_url = https://www.instagram.com/mike_beheshti
# user_url = https://www.instagram.com/cormac_ok99
# user_url = https://www.instagram.com/riyoosanai
# user_url = https://www.instagram.com/donblackcat
# user_url = https://www.instagram.com/keola
# user_url = https://www.instagram.com/dj_z00k
# user_url = https://www.instagram.com/5ive_ai
# user_url = https://www.instagram.com/eazylickz
# user_url = https://www.instagram.com/memeswithsound
# NoSuchElementException : //button[contains(text(),"Following")]
# NoSuchElementException : //button[contains(text(),"Unfollow")]
# user_url = https://www.instagram.com/statiicracing
# user_url = https://www.instagram.com/enemone.tv
# NoSuchElementException : //button[contains(text(),"Following")]
# NoSuchElementException : //button[contains(text(),"Unfollow")]
# user_url = https://www.instagram.com/smashletesgaming
# user_url = https://www.instagram.com/haviikthegoon
# user_url = https://www.instagram.com/saeicotv
# user_url = https://www.instagram.com/jumalalagit
# user_url = https://www.instagram.com/bo9o_
# user_url = https://www.instagram.com/gamersaddition
# user_url = https://www.instagram.com/gamer_2.0_zone
# user_url = https://www.instagram.com/call_of_laughters
# user_url = https://www.instagram.com/ferocious_harley
# user_url = https://www.instagram.com/_nika_tykhnova_
# user_url = https://www.instagram.com/x.mirachains
# NoSuchElementException : //button[contains(text(),"Following")]
# NoSuchElementException : //button[contains(text(),"Unfollow")]
# user_url = https://www.instagram.com/luxerybabes
# user_url = https://www.instagram.com/_she_is_a_devil__
# user_url = https://www.instagram.com/mychalsaray
# user_url = https://www.instagram.com/clipesdemaquiagens
# user_url = https://www.instagram.com/andraismygalaxy
# NoSuchElementException : //button[contains(text(),"Following")]
# NoSuchElementException : //button[contains(text(),"Unfollow")]
# user_url = https://www.instagram.com/ghetto.princessa_
# user_url = https://www.instagram.com/marks_browny
# user_url = https://www.instagram.com/missingyou_page
# user_url = https://www.instagram.com/ravenrage55
# user_url = https://www.instagram.com/z.a.e.b.i.s_
# user_url = https://www.instagram.com/pexumm
# user_url = https://www.instagram.com/blind_byakugan
# user_url = https://www.instagram.com/conrad_kc29
# user_url = https://www.instagram.com/old_account_so_yeah1
# user_url = https://www.instagram.com/itseileenoof
# user_url = https://www.instagram.com/stampthelamp_twitchtv
# NoSuchElementException : //button[contains(text(),"Following")]
# NoSuchElementException : //button[contains(text(),"Unfollow")]
# user_url = https://www.instagram.com/combatlasertag
# user_url = https://www.instagram.com/lknightmare661
# user_url = https://www.instagram.com/enzumore._.27_official
# user_url = https://www.instagram.com/rsgschwabmuenchen
# NoSuchElementException : //button[contains(text(),"Following")]
# NoSuchElementException : //button[contains(text(),"Unfollow")]
# user_url = https://www.instagram.com/raph10rules
# user_url = https://www.instagram.com/game.se7en
# user_url = https://www.instagram.com/stabberofficial
# user_url = https://www.instagram.com/mszmilly
# user_url = https://www.instagram.com/lwglasertag
# user_url = https://www.instagram.com/adimakinaruto93
# user_url = https://www.instagram.com/gamerlife_14
# user_url = https://www.instagram.com/denizkenankilic
# user_url = https://www.instagram.com/thestroppyone
# user_url = https://www.instagram.com/1inch_nail
# user_url = https://www.instagram.com/vitin27
# user_url = https://www.instagram.com/nattsu.t
# user_url = https://www.instagram.com/bleyfoto
# user_url = https://www.instagram.com/mondaychild2609
# user_url = https://www.instagram.com/sebis_picture_world
# user_url = https://www.instagram.com/gin_kojiro
# user_url = https://www.instagram.com/tomjcarty
# user_url = https://www.instagram.com/abandoned_utopia
# user_url = https://www.instagram.com/outbreaks_crew
# user_url = https://www.instagram.com/civil_ayre
# user_url = https://www.instagram.com/youresportsopinions
# user_url = https://www.instagram.com/cyber_news_ru
# user_url = https://www.instagram.com/mateofnm
# user_url = https://www.instagram.com/csglhf
# user_url = https://www.instagram.com/veaglee
# user_url = https://www.instagram.com/igc_clan
# user_url = https://www.instagram.com/hdwhitenigga
# user_url = https://www.instagram.com/wearespawn
# user_url = https://www.instagram.com/faze_the_fuck_up_
# user_url = https://www.instagram.com/cuthxr
# user_url = https://www.instagram.com/oijoelapede
# user_url = https://www.instagram.com/_3nv7_
# user_url = https://www.instagram.com/cars_things
# user_url = https://www.instagram.com/f_series_obs_ession
# user_url = https://www.instagram.com/maria.mezad
# user_url = https://www.instagram.com/evgeny_severin
# user_url = https://www.instagram.com/matthewscerr
# user_url = https://www.instagram.com/zeppeling1993
# user_url = https://www.instagram.com/hugrogers
# user_url = https://www.instagram.com/caiminjay
# user_url = https://www.instagram.com/jxlie.barb
# user_url = https://www.instagram.com/destiny.marie.poetry
# user_url = https://www.instagram.com/ohmysweetshawn
# user_url = https://www.instagram.com/leeernis
# user_url = https://www.instagram.com/rudi94_fotografie
# user_url = https://www.instagram.com/gilgameshisis
# user_url = https://www.instagram.com/sunagimo45_cyber
# user_url = https://www.instagram.com/sora_livana
# user_url = https://www.instagram.com/marcrileyart
# user_url = https://www.instagram.com/laci.mehes
# user_url = https://www.instagram.com/brnibblett
# user_url = https://www.instagram.com/lavi.kodakara.jomon
# user_url = https://www.instagram.com/ruin_kihoon_lee
# user_url = https://www.instagram.com/through.the.residue
# user_url = https://www.instagram.com/blitz5andfriends
# user_url = https://www.instagram.com/kolorowaruin
# user_url = https://www.instagram.com/kennyxiao_dye_back_show
# user_url = https://www.instagram.com/ruin_napoli
# user_url = https://www.instagram.com/jadethescott
# user_url = https://www.instagram.com/theirocproject
# user_url = https://www.instagram.com/thet1dwriter
# user_url = https://www.instagram.com/deniseschichan
# user_url = https://www.instagram.com/supreme_katanaz
# user_url = https://www.instagram.com/yeetus_her_fetus_
# user_url = https://www.instagram.com/born_gamers_community
# user_url = https://www.instagram.com/skyyrhi
# user_url = https://www.instagram.com/insta_spectrum_avee
# user_url = https://www.instagram.com/kingsshanker
# user_url = https://www.instagram.com/pubglist
# user_url = https://www.instagram.com/zamierolhaizad
# user_url = https://www.instagram.com/discordsunuculari
# user_url = https://www.instagram.com/iamkristx
# user_url = https://www.instagram.com/cursedimagesw
# user_url = https://www.instagram.com/terbiyesizabla_
# user_url = https://www.instagram.com/oppai.inc
# user_url = https://www.instagram.com/rockfaceconstruction
# runtime = -7509.04079914093
# end = 2019-05-19 17:37:33.560517
