# %%
import pandas as pd
import numpy as np

# load accounts & info on followed
follows_users = pd.read_csv('data/follows_users_ttv_princearthur_20190421_2205.csv')
# load accounts & info on following
by_users = pd.read_csv('data/followed_by_users_ttv_princearthru_20190421_1846.csv')

# %%
follows_users.head()

# %%
by_users.head()

# %%
len(follows_users.columns),len(by_users.columns),sum(follows_users.columns == by_users.columns),sum(follows_users.columns != by_users.columns)

# %%
follows_users.user_profile.head()

# %%
by_users.user_profile.head()

# %%
len(follows_users.user_profile),len(by_users.user_profile)

# %%
"""ACTUAL"""
# 7,289 following
# 1,479 followers
pass

# %% [markdown]
# - ***notes***:
#     - 2 over on followers
#     - 1 over on following

# %%
# collection of people we follow who are following us
followers_being_followed = [user for user in follows_users.username if user in by_users.username]
# collection of people we follow who are NOT following us
non_followers_being_followed = [user for user in follows_users.username if user not in by_users.username]

# %%
len(followers_being_followed),len(non_followers_being_followed)

# %%
by_users.loc[by_users.username == 'winstonr2']

# %%
follows_users.loc[follows_users.username == 'winstonr2']

# %%
by_usernames = np.array(by_users.user_profile)
follows_usernames = np.array(follows_users.user_profile)

# %%
# count coexisting
_=0
for i in follows_usernames:
    if i in by_usernames:
        _+=1
print(_)

# %% [markdown]
# - ***actions***:
#     - we will unfollow all except 669 users

# %%
# collect urls to profiles to unfollow 
unfollow_these = [user for user in follows_usernames if user not in by_usernames]
# collect urls to keep (double check overlap)
keep_these = [user for user in follows_usernames if user in by_usernames]

# %%
# check overlap
safe_check = 0
for user in keep_these:
    if user in unfollow_these:
        raise Exception('f')
    else:
        safe_check += 1
# double check overlap
if safe_check != len(keep_these):
    raise Exception('ff')

# %%
print(unfollow_these[0])

# %% [markdown]
# - ***notes***:
#     - ready for unfollowin
# - ***actions***:
#     - take list to Selenium webdriver (likely gecko)
#         - load page of user being followed
#             - click following button
#                 - click unfollowing button
#         - repeat

# %%
following_button = '.vBF20'
unfollow_button = 'button.aOOlW:nth-child(1)'

# %%
unfollow_these[:100]

# %%
import datetime
x = datetime.datetime.now()

# %%
x

# %%
# BREAK

# %%
# time it 
import time
# start time
now = time.time()
print(f"start = {datetime.datetime.now()}")

# for loading and sorting data regarding accounts of interest 
import numpy as np
import pandas as pd
# for taking action on accounts of interest
from time import sleep
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
# for documentation
import csv
import datetime
# loading login info (adjust to import yours or take this line out and input near bottom)
from _pile import utv, ptv

# load accounts & info on followed
follows_users = pd.read_csv('data/follows_users_ttv_princearthur_20190421_2205.csv')
# load accounts & info on following
by_users = pd.read_csv('data/followed_by_users_ttv_princearthru_20190421_1846.csv')

# url of each account following us
by_usernames = np.array(by_users.user_profile)
# url of each account we follow
follows_usernames = np.array(follows_users.user_profile)

# collect urls of profiles to unfollow 
unfollow_these = [user for user in follows_usernames if user not in by_usernames]
# collect urls of profiles we do NOT want to unfollow (double check overlap)
keep_these = [user for user in follows_usernames if user in by_usernames]

# set count for safety check (make sure we don't unfollow anyone we don't want to)
safe_check = 0
# check overlap
for user in keep_these:
    # does user coexist?
    if user in unfollow_these:
        # display it
        raise Exception(f'if user in unfollow_these : {user}')
    # otherwise
    else:
        # add to count of non coexisting
        safe_check += 1
# double check overlap via count
if safe_check != len(keep_these):
    # display unequal counts
    raise Exception(f'safe_check != len(keep_these) : {safe_check} != {len(keep_these)}')
    
# create csv to store accounts we have unfollowed (so do not re-follow in future)
with open('accounts_ttvpa_used_to_follow.csv', 'a', newline='') as file:
    # set writer to this file
    the_writer = csv.writer(file)
    # write column names
    the_writer.writerow(['account_id','username','profile_url','time_unfollowed'])
    

# geckodriver options setup
options = webdriver.FirefoxOptions()  
# block popups (set push notifications to False)
options.set_preference('dom.push.enabled', False) 

# set instagram.com
instagram = "https://www.instagram.com/"
# set path for login button from instagram.com (xpath)
log_in = "//a[@href='/accounts/login/?source=auth_switcher']"
# set path for user box for login page (xpath)
user_box = "//input[@name='username']"
# set path for password box for login page (xpath)
pass_box = "//input[@name='password']"

# define how we will log in 
def login(usr, pwd, driver):
    """
    logs in to instagram 
    
    inputs) 
        >> usr
            > username, email, or phone number of account 
        >> pwd
            > password of account 
        >> driver
            > webdriver being used (pre-defined)
    """
    # load base instagram 
    driver.get(instagram)
    # hedge load time and misc
    sleep(3)
    # find and tag the login button 
    login_button = driver.find_element_by_xpath(log_in)
    # click to login
    login_button.click()
    # hedge load time and etc..
    sleep(3)
    # find and tag the username, email, or phone number box
    user_name_elem = driver.find_element_by_xpath(user_box)
    # delete anything that may be in there
    user_name_elem.clear()
    # type in our user info 
    user_name_elem.send_keys(usr)
    # take a breath
    sleep(1)
    # find and tag the pass box
    passworword_elem = driver.find_element_by_xpath(pass_box)
    # clear out anything that may be in there
    passworword_elem.clear()
    # plug in our pass info 
    passworword_elem.send_keys(pwd)
    # take a breath
    sleep(1)
    # effectively hit 'enter' (logging in)
    passworword_elem.send_keys(Keys.RETURN)
    # and give it a bit to process, maybe extra load time, etc..
    sleep(3)

# set username 
user = utv
# set passwrd
pwrd = ptv

# id css selector for 'following' button
following_button = '.vBF20'
# id css selector for 'unfollow' button
unfollow_button = 'button.aOOlW:nth-child(1)'

# set webdriver w/ options (activates driver, screen should appear)
driver = webdriver.Firefox(options=options) 

# log in so we can get it poppin 
login(usr=user, pwd=pwrd, driver=driver)

# define unfollow method and process 
def unfollow(accounts=unfollow_these, n=100):
    """
    goes through list of accounts
        loads the current account's profile url
            makes sure that account is cleared for unfollowing
                unfollows the account 
    inputs)
        >> accounts
            > list of accounts eligible for unfollowing
        >> n
            > number of those accounts we're going to unfollow right now
                >> rec: n < 250 , due to mass unfollowing (usually) being prohibited 
                >> default: 1 (i.e. two (2) accounts)
    """
    # go through first n urls
    for user_url in accounts[5:n]:
        print(f'user_url = {user_url}')  # for testing
        """
        prime the mission
        """
        # load the url
        driver.get(user_url)
        # wait for profile page to load
        sleep(3)
        # find and click the 'following' button 
        driver.find_element_by_css_selector(following_button).click()
        # wait a bit (to seem human, for web loading, and not unfollow too quickly)
        sleep(2)
        """
        set up recording of transaction
        """
        # pull the account's record
        this_account = follows_users.loc[follows_users.user_profile == user_url]
        # account's id number
        account_id = this_account.id
        for i in account_id:
            account_id = i
        # account's username
        username = this_account.username
        for i in username:
            username = i
        # account's url
        profile_url = this_account.user_profile
        for i in profile_url:
            profile_url = i
        # double check
        if str(profile_url) != str(user_url):
            # let us know if it's not adding up 
            raise Exception(f'profile_url != user_url : {profile_url} != {user_url}')
        # set values to be recorded 
        fields = [account_id, username, profile_url, datetime.datetime.now()]
        """
        execute
        """
        # find and click 'unfollow' button in popup 
        driver.find_element_by_css_selector(unfollow_button).click()
        """
        record the transaction
        """
        # open up the csv
        with open('accounts_ttvpa_used_to_follow.csv', 'a') as _f:
            # fit the writer
            writer = csv.writer(_f)
            # document the transaction
            writer.writerow(fields)
        # pause so we can do this for a long time without breaching the unfollow limit 
        sleep(16)  # combined sleep prior = 16 sec; +16 = 32; +runtime ~40??
        # believe it to be: 160/hour; with this we will hit about 90 an hour 

# let's do it (399 accounts)
unfollow(accounts=unfollow_these, n=404)
# end time
then = time.time()
# how long did this take?
runtime = now-then
# show us
print(f"runtime = {runtime}")
print(f"end = {datetime.datetime.now()}")
# Out:
# start = 2019-04-23 00:09:58.548097
# user_url = https://www.instagram.com/ninja
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0c6f767c82ee> in <module>
#     203
#     204 # let's do it (399 accounts)
# --> 205 unfollow(accounts=unfollow_these, n=404)
#     206 # end time
#     207 then = time.time()
#
# <ipython-input-10-0c6f767c82ee> in unfollow(accounts, n)
#     199             writer.writerow(fields)
#     200         # pause so we can do this for a long time without breaching the unfollow limit
# --> 201         sleep(16)  # combined sleep prior = 16 sec; +16 = 32; +runtime ~40??
#     202         # believe it to be: 160/hour; with this we will hit about 90 an hour
#     203
#
# KeyboardInterrupt:

# %%
len(unfollow_these[5:404])
# Out:
# 399

# %%
unfollow_these[5:404]
# Out:
# ['https://www.instagram.com/abdul.rafay_11',
#  'https://www.instagram.com/theofficialgibbay',
#  'https://www.instagram.com/andersonpsgames',
#  'https://www.instagram.com/the_wolfe_pac',
#  'https://www.instagram.com/aresthevillain',
#  'https://www.instagram.com/playstationinfo.access',
#  'https://www.instagram.com/jammyjimjay',
#  'https://www.instagram.com/realhksmash',
#  'https://www.instagram.com/dekori_5513',
#  'https://www.instagram.com/jsmondays',
#  'https://www.instagram.com/guntursyabani',
#  'https://www.instagram.com/shazad_khan11',
#  'https://www.instagram.com/_frank.1k',
#  'https://www.instagram.com/jacobray.jpeg',
#  'https://www.instagram.com/nphoangminh',
#  'https://www.instagram.com/camtheman1215',
#  'https://www.instagram.com/succcccccccccccc',
#  'https://www.instagram.com/jmdbeast417',
#  'https://www.instagram.com/saklain_1169only',
#  'https://www.instagram.com/gamingstash',
#  'https://www.instagram.com/blazercentral9212',
#  'https://www.instagram.com/cody_austin_brown',
#  'https://www.instagram.com/rootedinspiration',
#  'https://www.instagram.com/keem_sodmg',
#  'https://www.instagram.com/mauriceall2',
#  'https://www.instagram.com/diogoluis1304',
#  'https://www.instagram.com/angelo.abrego_',
#  'https://www.instagram.com/kxng_blaze68',
#  'https://www.instagram.com/nolimitjrv',
#  'https://www.instagram.com/baysickm8',
#  'https://www.instagram.com/moztdo93',
#  'https://www.instagram.com/xboxdead',
#  'https://www.instagram.com/viralstattoo',
#  'https://www.instagram.com/exploration.addict',
#  'https://www.instagram.com/ze_limia',
#  'https://www.instagram.com/victor_vansuita',
#  'https://www.instagram.com/clear.fit.girls',
#  'https://www.instagram.com/_insta__kour____2',
#  'https://www.instagram.com/travel_green_',
#  'https://www.instagram.com/ldr_vids',
#  'https://www.instagram.com/underwwood',
#  'https://www.instagram.com/callme_totones',
#  'https://www.instagram.com/keviin_0412',
#  'https://www.instagram.com/ian.schumacher17',
#  'https://www.instagram.com/_.frankogallardo',
#  'https://www.instagram.com/johnjohn.1320',
#  'https://www.instagram.com/hail.thecesar',
#  'https://www.instagram.com/hrh90',
#  'https://www.instagram.com/captain5522',
#  'https://www.instagram.com/thomasermen',
#  'https://www.instagram.com/jlesan55',
#  'https://www.instagram.com/shamz_mk7',
#  'https://www.instagram.com/jesusgarciaolivarez',
#  'https://www.instagram.com/jamiesmith155',
#  'https://www.instagram.com/dani_auraa',
#  'https://www.instagram.com/iamvincenzoarcudi',
#  'https://www.instagram.com/_piqies',
#  'https://www.instagram.com/rolicobo',
#  'https://www.instagram.com/ezekiel_romero',
#  'https://www.instagram.com/diegomena0103',
#  'https://www.instagram.com/webby__98',
#  'https://www.instagram.com/codystanowski',
#  'https://www.instagram.com/marques_1488',
#  'https://www.instagram.com/b.wavyy',
#  'https://www.instagram.com/yannics2.acc',
#  'https://www.instagram.com/marcusenergize',
#  'https://www.instagram.com/chazzwell_',
#  'https://www.instagram.com/mexican4119',
#  'https://www.instagram.com/foldmeister2',
#  'https://www.instagram.com/sadaa_csgo',
#  'https://www.instagram.com/complx.ees',
#  'https://www.instagram.com/mike.born23',
#  'https://www.instagram.com/yungmpaimp',
#  'https://www.instagram.com/carsonhoff6m',
#  'https://www.instagram.com/killerman5007',
#  'https://www.instagram.com/munagalasubhash',
#  'https://www.instagram.com/av0n_expert',
#  'https://www.instagram.com/ilgarlando',
#  'https://www.instagram.com/starboy_arunn',
#  'https://www.instagram.com/journeytograndmaster',
#  'https://www.instagram.com/harxhh',
#  'https://www.instagram.com/wsjrealestate',
#  'https://www.instagram.com/realestate',
#  'https://www.instagram.com/manic_panic89',
#  'https://www.instagram.com/chrispin_crunch',
#  'https://www.instagram.com/gamelicious_girl',
#  'https://www.instagram.com/itslethalttv',
#  'https://www.instagram.com/blakeharris._',
#  'https://www.instagram.com/smh.joel',
#  'https://www.instagram.com/powercrunchtv',
#  'https://www.instagram.com/jumbo3315',
#  'https://www.instagram.com/twalkman_13',
#  'https://www.instagram.com/_aryan_hasbi_',
#  'https://www.instagram.com/mohdfadhlikarami',
#  'https://www.instagram.com/rizkyfadillahxd',
#  'https://www.instagram.com/shroud',
#  'https://www.instagram.com/playboi__dee',
#  'https://www.instagram.com/jackblenn',
#  'https://www.instagram.com/fat_bubs',
#  'https://www.instagram.com/_trentdodson',
#  'https://www.instagram.com/boujee.baig',
#  'https://www.instagram.com/joe._.scott',
#  'https://www.instagram.com/insanity______________',
#  'https://www.instagram.com/mason_lax59',
#  'https://www.instagram.com/king_nun3z05',
#  'https://www.instagram.com/kimkardashian',
#  'https://www.instagram.com/aniita__7',
#  'https://www.instagram.com/thatlilchick',
#  'https://www.instagram.com/anggelsamaniego',
#  'https://www.instagram.com/mememasterbb',
#  'https://www.instagram.com/niek07ajax',
#  'https://www.instagram.com/cloutgangvibes_',
#  'https://www.instagram.com/brown_zakk',
#  'https://www.instagram.com/miguel_salgado24',
#  'https://www.instagram.com/blainehix_basketball',
#  'https://www.instagram.com/st___alin',
#  'https://www.instagram.com/ashbremner_',
#  'https://www.instagram.com/_ted.m_14',
#  'https://www.instagram.com/oswag613',
#  'https://www.instagram.com/vance_chirempes',
#  'https://www.instagram.com/joshua_harker17',
#  'https://www.instagram.com/gavin.molina.71',
#  'https://www.instagram.com/_mr_besharam_',
#  'https://www.instagram.com/ivosp_22',
#  'https://www.instagram.com/vahid_tem_2000',
#  'https://www.instagram.com/lannysaint1',
#  'https://www.instagram.com/rishabhsharma7693',
#  'https://www.instagram.com/afryanyoga',
#  'https://www.instagram.com/ariefd92',
#  'https://www.instagram.com/ayy._.itsjoe',
#  'https://www.instagram.com/the_grapeking',
#  'https://www.instagram.com/jek0_barwary',
#  'https://www.instagram.com/farhanindlubis',
#  'https://www.instagram.com/ryanbatata.nha',
#  'https://www.instagram.com/eduardo___araujo',
#  'https://www.instagram.com/chinnu_lucky_',
#  'https://www.instagram.com/abbe_uptown',
#  'https://www.instagram.com/jorge_3_3_98_',
#  'https://www.instagram.com/lowcarbreceitasdieta',
#  'https://www.instagram.com/sittichaijunjak',
#  'https://www.instagram.com/adamorul',
#  'https://www.instagram.com/bhosalenachiket',
#  'https://www.instagram.com/hoaitran20.07',
#  'https://www.instagram.com/carlosbervig',
#  'https://www.instagram.com/sa1d.rfq',
#  'https://www.instagram.com/kenhuynhz3',
#  'https://www.instagram.com/pascutudorr',
#  'https://www.instagram.com/lhlupuii',
#  'https://www.instagram.com/mrwafi30',
#  'https://www.instagram.com/justintran37',
#  'https://www.instagram.com/eliottboison_32',
#  'https://www.instagram.com/feernanda.carcaamo',
#  'https://www.instagram.com/workout.course',
#  'https://www.instagram.com/otaku_korabeka',
#  'https://www.instagram.com/ultimaworkout',
#  'https://www.instagram.com/t0mvsss_',
#  'https://www.instagram.com/bodybuildingdifference',
#  'https://www.instagram.com/ucef_elkawkabi',
#  'https://www.instagram.com/bodybuildingedge',
#  'https://www.instagram.com/davids_gallo',
#  'https://www.instagram.com/workoutparticipate',
#  'https://www.instagram.com/saltinekracker',
#  'https://www.instagram.com/friendsofxbox',
#  'https://www.instagram.com/dani.rabah2008',
#  'https://www.instagram.com/ayebreezy1',
#  'https://www.instagram.com/fitnesssection',
#  'https://www.instagram.com/rfl_troll',
#  'https://www.instagram.com/maniga_berenger',
#  'https://www.instagram.com/doccyjjjjj',
#  'https://www.instagram.com/yakumodo',
#  'https://www.instagram.com/ofxz.alts',
#  'https://www.instagram.com/examfitness_',
#  'https://www.instagram.com/undercover_pp',
#  'https://www.instagram.com/roman.premier',
#  'https://www.instagram.com/rodeorealty',
#  'https://www.instagram.com/realestatewithcelestenyc',
#  'https://www.instagram.com/therealdeal',
#  'https://www.instagram.com/floydmayweather',
#  'https://www.instagram.com/nickiminaj',
#  'https://www.instagram.com/tydollasign',
#  'https://www.instagram.com/chrisbrownofficial',
#  'https://www.instagram.com/lifeofdesiigner',
#  'https://www.instagram.com/migos',
#  'https://www.instagram.com/champagnepapi',
#  'https://www.instagram.com/gameandvideostore',
#  'https://www.instagram.com/benjamintheobold91',
#  'https://www.instagram.com/kalii.carter',
#  'https://www.instagram.com/mrbadcannon',
#  'https://www.instagram.com/kingdomofgaming',
#  'https://www.instagram.com/glendrick_perkins',
#  'https://www.instagram.com/hartcoletwitch',
#  'https://www.instagram.com/nepharyel',
#  'https://www.instagram.com/katyrose9',
#  'https://www.instagram.com/caliomask',
#  'https://www.instagram.com/joshdeog',
#  'https://www.instagram.com/iclaphard',
#  'https://www.instagram.com/eveary._',
#  'https://www.instagram.com/atcertainwolf',
#  'https://www.instagram.com/kaynnbeyyedek',
#  'https://www.instagram.com/a_lightskinnamed_daelin',
#  'https://www.instagram.com/keeley_gunn',
#  'https://www.instagram.com/d3patie',
#  'https://www.instagram.com/regenerates',
#  'https://www.instagram.com/unfz_pac_87',
#  'https://www.instagram.com/saimon_diz',
#  'https://www.instagram.com/zevcandraw',
#  'https://www.instagram.com/ieod',
#  'https://www.instagram.com/low_end_gaming',
#  'https://www.instagram.com/gaming_with_studzzx',
#  'https://www.instagram.com/callofspeedy',
#  'https://www.instagram.com/toyfiend',
#  'https://www.instagram.com/twixxtaylor',
#  'https://www.instagram.com/royal_gam3r',
#  'https://www.instagram.com/favored_mods',
#  'https://www.instagram.com/zw.q1',
#  'https://www.instagram.com/mvfs4',
#  'https://www.instagram.com/callofduty.24seven',
#  'https://www.instagram.com/seanbartleyontwitch',
#  'https://www.instagram.com/galactic_cutiee',
#  'https://www.instagram.com/crillskillzgaming',
#  'https://www.instagram.com/indica_prince',
#  'https://www.instagram.com/juliet.whiskey1',
#  'https://www.instagram.com/nerdybird007',
#  'https://www.instagram.com/retrospekt12',
#  'https://www.instagram.com/cizgiedit',
#  'https://www.instagram.com/yelo',
#  'https://www.instagram.com/official_spammarkus',
#  'https://www.instagram.com/_alissathesoftest',
#  'https://www.instagram.com/team.butarda',
#  'https://www.instagram.com/xyttoxbl',
#  'https://www.instagram.com/bh.unfazed',
#  'https://www.instagram.com/tfueshands',
#  'https://www.instagram.com/duofnsns',
#  'https://www.instagram.com/itzloobzhd',
#  'https://www.instagram.com/nlmbwrld',
#  'https://www.instagram.com/faze_fresh',
#  'https://www.instagram.com/team.bbg',
#  'https://www.instagram.com/ayymako',
#  'https://www.instagram.com/ttgxgreenbean',
#  'https://www.instagram.com/_daily_laughter_._',
#  'https://www.instagram.com/fortnitevxx',
#  'https://www.instagram.com/pulseggs',
#  'https://www.instagram.com/arbyswifi',
#  'https://www.instagram.com/faze.cloutgang',
#  'https://www.instagram.com/xumio_',
#  'https://www.instagram.com/seek.the.memes',
#  'https://www.instagram.com/fear.gg',
#  'https://www.instagram.com/veralynnpics',
#  'https://www.instagram.com/corymyglory',
#  'https://www.instagram.com/lego_my_lego13',
#  'https://www.instagram.com/jane_mairead',
#  'https://www.instagram.com/otfhudson',
#  'https://www.instagram.com/shubhampaul_offical',
#  'https://www.instagram.com/allof_myu',
#  'https://www.instagram.com/cateringtusantojos',
#  'https://www.instagram.com/segundotiempomx',
#  'https://www.instagram.com/beseraphic',
#  'https://www.instagram.com/meee_bitchhhh',
#  'https://www.instagram.com/de_goan_crew',
#  'https://www.instagram.com/guptasaurav',
#  'https://www.instagram.com/chittgongmeme',
#  'https://www.instagram.com/cantrellcuestas',
#  'https://www.instagram.com/90simmy90',
#  'https://www.instagram.com/_eagora.mae',
#  'https://www.instagram.com/shoesonline0000',
#  'https://www.instagram.com/sharmayogesh__',
#  'https://www.instagram.com/ruivosinspiracoes',
#  'https://www.instagram.com/finalcreationphotography',
#  'https://www.instagram.com/_breakup_.diary',
#  'https://www.instagram.com/investinginmemes',
#  'https://www.instagram.com/loly36z',
#  'https://www.instagram.com/galiova_valoria',
#  'https://www.instagram.com/jakekassi',
#  'https://www.instagram.com/safadogan',
#  'https://www.instagram.com/theduskywoman_',
#  'https://www.instagram.com/hindol.10',
#  'https://www.instagram.com/_cavie',
#  'https://www.instagram.com/mizzsynspe',
#  'https://www.instagram.com/clips_zeko',
#  'https://www.instagram.com/jozzypants',
#  'https://www.instagram.com/teamuntold',
#  'https://www.instagram.com/bunny_fam_ttv',
#  'https://www.instagram.com/sixturefn',
#  'https://www.instagram.com/the_giovanno',
#  'https://www.instagram.com/justvember',
#  'https://www.instagram.com/iamthekptv',
#  'https://www.instagram.com/ryden.twitch',
#  'https://www.instagram.com/doryuuz',
#  'https://www.instagram.com/toofar_artwork',
#  'https://www.instagram.com/jriii3.tv',
#  'https://www.instagram.com/kaeldainvoker',
#  'https://www.instagram.com/sunder_strike',
#  'https://www.instagram.com/elpicante_',
#  'https://www.instagram.com/officialdesmar',
#  'https://www.instagram.com/ttv.gamerjordan_',
#  'https://www.instagram.com/propokenoob',
#  'https://www.instagram.com/becanchi',
#  'https://www.instagram.com/whothefisjc',
#  'https://www.instagram.com/apollodoro5',
#  'https://www.instagram.com/mitsuki_ttv',
#  'https://www.instagram.com/elreinotv',
#  'https://www.instagram.com/clinton_benhart',
#  'https://www.instagram.com/jaye.flow',
#  'https://www.instagram.com/mattybuj',
#  'https://www.instagram.com/thrashparty',
#  'https://www.instagram.com/saucyhex',
#  'https://www.instagram.com/mrob29',
#  'https://www.instagram.com/opseatgaming',
#  'https://www.instagram.com/ryphol',
#  'https://www.instagram.com/eglxofficial',
#  'https://www.instagram.com/dante_the_demon_killer1',
#  'https://www.instagram.com/sithismalkira',
#  'https://www.instagram.com/alphaclubir',
#  'https://www.instagram.com/sw4p',
#  'https://www.instagram.com/reaperlordsmotorcycleclub',
#  'https://www.instagram.com/jakespeed43',
#  'https://www.instagram.com/pallyson_420',
#  'https://www.instagram.com/thatsmriq',
#  'https://www.instagram.com/jolt.uprising',
#  'https://www.instagram.com/_blessedxo',
#  'https://www.instagram.com/godzz_fortnite_gangzzzzz',
#  'https://www.instagram.com/elementssalonstudio',
#  'https://www.instagram.com/monster__cody',
#  'https://www.instagram.com/afellan14th',
#  'https://www.instagram.com/therealsneakysneek',
#  'https://www.instagram.com/teamjalapano',
#  'https://www.instagram.com/gamesrelatedstuff',
#  'https://www.instagram.com/openmountaintv',
#  'https://www.instagram.com/6sixfeetdown',
#  'https://www.instagram.com/altasrustlerlodge',
#  'https://www.instagram.com/fortnitefiasco',
#  'https://www.instagram.com/gorilla.nut',
#  'https://www.instagram.com/memecrasher',
#  'https://www.instagram.com/flfyog',
#  'https://www.instagram.com/beezo0',
#  'https://www.instagram.com/blazeganjah',
#  'https://www.instagram.com/blackops4brasil',
#  'https://www.instagram.com/braedenow',
#  'https://www.instagram.com/acescomics',
#  'https://www.instagram.com/itswoozea',
#  'https://www.instagram.com/ac1d_420',
#  'https://www.instagram.com/you_know_duck',
#  'https://www.instagram.com/the.real.blitz',
#  'https://www.instagram.com/bo4_pictures',
#  'https://www.instagram.com/staxtics',
#  'https://www.instagram.com/theblackopshub',
#  'https://www.instagram.com/jeystron',
#  'https://www.instagram.com/brannon_s_wood',
#  'https://www.instagram.com/lennoxmasonry',
#  'https://www.instagram.com/cncswede',
#  'https://www.instagram.com/adamcaaksesuar',
#  'https://www.instagram.com/aschultephotography',
#  'https://www.instagram.com/waytogobuilders',
#  'https://www.instagram.com/stacysorboro',
#  'https://www.instagram.com/c.c.agnew',
#  'https://www.instagram.com/arworkshopmason',
#  'https://www.instagram.com/jonny_rose',
#  'https://www.instagram.com/getrealstone',
#  'https://www.instagram.com/macattackmason',
#  'https://www.instagram.com/thebomb006.tv',
#  'https://www.instagram.com/alm4n4k',
#  'https://www.instagram.com/chrisxianf5',
#  'https://www.instagram.com/elvinuhu',
#  'https://www.instagram.com/bazontwitch',
#  'https://www.instagram.com/blackouttvytb',
#  'https://www.instagram.com/jamie_jason94',
#  'https://www.instagram.com/badsodagaming',
#  'https://www.instagram.com/sellout_central',
#  'https://www.instagram.com/saiyangamegirl',
#  'https://www.instagram.com/pakkxking',
#  'https://www.instagram.com/badog187cc',
#  'https://www.instagram.com/dunstonmc',
#  'https://www.instagram.com/hispanicti7anic',
#  'https://www.instagram.com/171727_ui',
#  'https://www.instagram.com/dujdudyt',
#  'https://www.instagram.com/bigern_gaming',
#  'https://www.instagram.com/kingdobber',
#  'https://www.instagram.com/op_gamingsetups',
#  'https://www.instagram.com/hyperkind808',
#  'https://www.instagram.com/holmsedits',
#  'https://www.instagram.com/seslorgames',
#  'https://www.instagram.com/angryguido',
#  'https://www.instagram.com/mayssk_',
#  'https://www.instagram.com/gaming4lifebe',
#  'https://www.instagram.com/julie.glv',
#  'https://www.instagram.com/mistakex_accountss',
#  'https://www.instagram.com/juanmainiok',
#  'https://www.instagram.com/actionsenpai',
#  'https://www.instagram.com/_losmejoresclipsfortnite',
#  'https://www.instagram.com/goodstuffforjustin',
#  'https://www.instagram.com/deinroxas',
#  'https://www.instagram.com/ddeelleteddddd',
#  'https://www.instagram.com/itsmegagemc',
#  'https://www.instagram.com/318gaming',
#  'https://www.instagram.com/azalia_cowlin',
#  'https://www.instagram.com/wild8159',
#  'https://www.instagram.com/teamgaslighters',
#  'https://www.instagram.com/bloodhoundgent',
#  'https://www.instagram.com/wazz_gangsta_']
